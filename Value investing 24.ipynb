# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\shanj\Downloads\2020Q1Q2Q3Q4-2021Q1 - Russia - Sberbank Rossii PAO (SBER).csv')
df=df.dropna()
print('Shape of data',df.shape)
df.head()
df
# Out:
# Shape of data (311, 7)
#              Date   Price    Open    High     Low    Vol. Change %
# 0    Mar 31, 2021  291.02     294  294.42  290.26  47.00M   -0.76%
# 1    Mar 30, 2021  293.25  294.86  295.72   291.5  38.81M   -0.02%
# 2    Mar 29, 2021   293.3  289.72  294.09  289.26  43.68M    0.71%
# 3    Mar 26, 2021  291.22  288.63  292.75  288.32  56.07M    1.59%
# 4    Mar 25, 2021  286.66   286.5  287.03  283.85  35.22M    0.30%
# ..            ...     ...     ...     ...     ...     ...      ...
# 306  Jan 10, 2020  258.19  257.86  259.25  256.88  18.85M    0.08%
# 307  Jan 09, 2020  257.99   259.4  261.76  257.01  38.33M   -0.45%
# 308  Jan 08, 2020  259.15  253.57  259.15  253.03  40.82M    2.07%
# 309  Jan 06, 2020   253.9  254.75  254.84   251.4  22.35M   -0.43%
# 310  Jan 03, 2020     255  255.99  258.19   253.7  35.85M    0.10%
#
# [311 rows x 7 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# Convert date column to yyyy-mm-dd format
df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')


df=df.sort_values(by=['Date'])

print(df)
# Out:
#            Date   Price    Open    High     Low    Vol. Change %
# 310  2020-01-03     255  255.99  258.19   253.7  35.85M    0.10%
# 309  2020-01-06   253.9  254.75  254.84   251.4  22.35M   -0.43%
# 308  2020-01-08  259.15  253.57  259.15  253.03  40.82M    2.07%
# 307  2020-01-09  257.99   259.4  261.76  257.01  38.33M   -0.45%
# 306  2020-01-10  258.19  257.86  259.25  256.88  18.85M    0.08%
# ..          ...     ...     ...     ...     ...     ...      ...
# 4    2021-03-25  286.66   286.5  287.03  283.85  35.22M    0.30%
# 3    2021-03-26  291.22  288.63  292.75  288.32  56.07M    1.59%
# 2    2021-03-29   293.3  289.72  294.09  289.26  43.68M    0.71%
# 1    2021-03-30  293.25  294.86  295.72   291.5  38.81M   -0.02%
# 0    2021-03-31  291.02     294  294.42  290.26  47.00M   -0.76%
#
# [311 rows x 7 columns]

# %%
df1=df

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1
# Out:
#            Date   Price    Open    High     Low    Vol. Change %
# 0    2020-01-03     255  255.99  258.19   253.7  35.85M    0.10%
# 1    2020-01-06   253.9  254.75  254.84   251.4  22.35M   -0.43%
# 2    2020-01-08  259.15  253.57  259.15  253.03  40.82M    2.07%
# 3    2020-01-09  257.99   259.4  261.76  257.01  38.33M   -0.45%
# 4    2020-01-10  258.19  257.86  259.25  256.88  18.85M    0.08%
# ..          ...     ...     ...     ...     ...     ...      ...
# 306  2021-03-25  286.66   286.5  287.03  283.85  35.22M    0.30%
# 307  2021-03-26  291.22  288.63  292.75  288.32  56.07M    1.59%
# 308  2021-03-29   293.3  289.72  294.09  289.26  43.68M    0.71%
# 309  2021-03-30  293.25  294.86  295.72   291.5  38.81M   -0.02%
# 310  2021-03-31  291.02     294  294.42  290.26  47.00M   -0.76%
#
# [311 rows x 7 columns]

# %%
df1.dtypes
# Out:
# Date        object
# Price       object
# Open        object
# High        object
# Low         object
# Vol.        object
# Change %    object
# dtype: object

# %%
df1['Date'] = pd.to_datetime(df1['Date'])

# %%
df1['Price'] = pd.to_numeric(df1['Price'], errors='coerce')

# %%
train_data = df1[df1['Date'] <= '2020-12-30']

# %%
train_data
# Out:
#           Date   Price    Open    High     Low    Vol. Change %
# 0   2020-01-03  255.00  255.99  258.19   253.7  35.85M    0.10%
# 1   2020-01-06  253.90  254.75  254.84   251.4  22.35M   -0.43%
# 2   2020-01-08  259.15  253.57  259.15  253.03  40.82M    2.07%
# 3   2020-01-09  257.99   259.4  261.76  257.01  38.33M   -0.45%
# 4   2020-01-10  258.19  257.86  259.25  256.88  18.85M    0.08%
# ..         ...     ...     ...     ...     ...     ...      ...
# 245 2020-12-24  269.32  271.98  272.82  267.13  42.61M   -0.29%
# 246 2020-12-25  270.64  269.97     271  268.28  11.99M    0.49%
# 247 2020-12-28  274.70   270.9  275.19  269.73  39.04M    1.50%
# 248 2020-12-29  272.00  275.91  276.43  271.26  39.02M   -0.98%
# 249 2020-12-30  271.65  272.49  274.24  270.12  31.53M   -0.13%
#
# [250 rows x 7 columns]

# %%
train_data = df1[df1['Date'] <= '2020-12-31']
test_data=df1[df1['Date'] > '2020-12-31']

# %%
test_data.shape[0]
# Out:
# 61

# %%
import pmdarima as pm

# %%
auto_model = pm.auto_arima(train_data['Price'], seasonal=True, m=12)

# %%
print(auto_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  250
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -747.842
# Date:                Tue, 30 Apr 2024   AIC                           1497.685
# Time:                        12:47:49   BIC                           1501.202
# Sample:                             0   HQIC                          1499.101
#                                 - 250
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        23.7810      1.267     18.772      0.000      21.298      26.264
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.42   Jarque-Bera (JB):               142.35
# Prob(Q):                              0.52   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.50   Skew:                            -0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
df1.dtypes
# Out:
# Date        datetime64[ns]
# Price              float64
# Open                object
# High                object
# Low                 object
# Vol.                object
# Change %            object
# dtype: object

# %%
forecast = auto_model.predict(n_periods=1)

# %%
forecast.values[0]
# Out:
# 271.65

# %%
forecasted_price = forecast.iloc[0]
print("Forecasted stock price on January 1st, 2022:", forecasted_price)
# Out:
# Forecasted stock price on January 1st, 2022: 271.65

# %%
Predictions=[]

# %%
for step in range(test_data.shape[0]):
    if not train_data.empty:
        
        train_data = df1[df1['Date'] < test_data.iloc[step, 0]]
        #train_data=train_data['Date'].iloc[0, 0]
        # Fit auto ARIMA model
        auto_model = pm.auto_arima(train_data['Price'], seasonal=True, m=12)# m= number of seasonalites

        # Forecast the stock price for the next day
        forecast = auto_model.predict(n_periods=1)
        # Forecasting one period ahead

        # Print the forecast for the next day
        print("Forecasted stock price for the next day:", forecast.values[0])
        
        Predictions.append(forecast.values[0])

        # Update the training data by including the next day
     
    else:
        print("No data available for training on step", step + 1)
        break
# Out:
# Forecasted stock price for the next day: 271.65
# Forecasted stock price for the next day: 272.2943416539624
# Forecasted stock price for the next day: 274.4939264872108
# Forecasted stock price for the next day: 272.93
# Forecasted stock price for the next day: 283.64
# Forecasted stock price for the next day: 289.49
# Forecasted stock price for the next day: 289.99
# Forecasted stock price for the next day: 283.78
# Forecasted stock price for the next day: 284.79
# Forecasted stock price for the next day: 276.9
# Forecasted stock price for the next day: 279.79
# Forecasted stock price for the next day: 278.19
# Forecasted stock price for the next day: 279.8
# Forecasted stock price for the next day: 274.3999999999999
# Forecasted stock price for the next day: 268.25
# Forecasted stock price for the next day: 265.3
# Forecasted stock price for the next day: 269.34
# Forecasted stock price for the next day: 265.5
# Forecasted stock price for the next day: 265.96
# Forecasted stock price for the next day: 258.11
# Forecasted stock price for the next day: 263.8
# Forecasted stock price for the next day: 263.15
# Forecasted stock price for the next day: 263.53
# Forecasted stock price for the next day: 270.11
# Forecasted stock price for the next day: 271.7
# Forecasted stock price for the next day: 275.2
# Forecasted stock price for the next day: 268.98
# Forecasted stock price for the next day: 265.9
# Forecasted stock price for the next day: 264.7
# Forecasted stock price for the next day: 266.0
# Forecasted stock price for the next day: 271.81
# Forecasted stock price for the next day: 270.9
# Forecasted stock price for the next day: 270.9
# Forecasted stock price for the next day: 266.99
# Forecasted stock price for the next day: 271.34
# Forecasted stock price for the next day: 270.51
# Forecasted stock price for the next day: 273.71
# Forecasted stock price for the next day: 271.9
# Forecasted stock price for the next day: 270.71
# Forecasted stock price for the next day: 270.17
# Forecasted stock price for the next day: 273.58
# Forecasted stock price for the next day: 279.1
# Forecasted stock price for the next day: 278.01
# Forecasted stock price for the next day: 274.75
# Forecasted stock price for the next day: 277.5
# Forecasted stock price for the next day: 285.79
# Forecasted stock price for the next day: 282.24
# Forecasted stock price for the next day: 286.0
# Forecasted stock price for the next day: 284.93
# Forecasted stock price for the next day: 292.74
# Forecasted stock price for the next day: 292.33
# Forecasted stock price for the next day: 283.35
# Forecasted stock price for the next day: 279.25
# Forecasted stock price for the next day: 285.47
# Forecasted stock price for the next day: 288.65
# Forecasted stock price for the next day: 282.6
# Forecasted stock price for the next day: 285.79
# Forecasted stock price for the next day: 286.66
# Forecasted stock price for the next day: 291.22
# Forecasted stock price for the next day: 293.3
# Forecasted stock price for the next day: 293.25

# %%
Predictions
# Out:
# [271.65,
#  272.2943416539624,
#  274.4939264872108,
#  272.93,
#  283.64,
#  289.49,
#  289.99,
#  283.78,
#  284.79,
#  276.9,
#  279.79,
#  278.19,
#  279.8,
#  274.3999999999999,
#  268.25,
#  265.3,
#  269.34,
#  265.5,
#  265.96,
#  258.11,
#  263.8,
#  263.15,
#  263.53,
#  270.11,
#  271.7,
#  275.2,
#  268.98,
#  265.9,
#  264.7,
#  266.0,
#  271.81,
#  270.9,
#  270.9,
#  266.99,
#  271.34,
#  270.51,
#  273.71,
#  271.9,
#  270.71,
#  270.17,
#  273.58,
#  279.1,
#  278.01,
#  274.75,
#  277.5,
#  285.79,
#  282.24,
#  286.0,
#  284.93,
#  292.74,
#  292.33,
#  283.35,
#  279.25,
#  285.47,
#  288.65,
#  282.6,
#  285.79,
#  286.66,
#  291.22,
#  293.3,
#  293.25]

# %%
test_data.iloc[0, 0]
# Out:
# Timestamp('2021-01-04 00:00:00')

# %%
test_data['predictions']=Predictions
# Out:
# C:\Users\shanj\AppData\Local\Temp\ipykernel_31196\367764177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['predictions']=Predictions

# %%
test_data
# Out:
#           Date   Price    Open    High     Low     Vol. Change %  predictions
# 250 2021-01-04  272.00  274.67   276.6  270.61   48.92M    0.13%   271.650000
# 251 2021-01-05  275.20  272.69   275.7  270.28   45.58M    1.18%   272.294342
# 252 2021-01-06  272.93  275.94  275.94  271.62   40.95M   -0.82%   274.493926
# 253 2021-01-08  283.64  275.11  283.99  275.11   88.93M    3.92%   272.930000
# 254 2021-01-11  289.49  282.86  292.95  279.48  112.35M    2.06%   283.640000
# ..         ...     ...     ...     ...     ...      ...      ...          ...
# 306 2021-03-25  286.66   286.5  287.03  283.85   35.22M    0.30%   285.790000
# 307 2021-03-26  291.22  288.63  292.75  288.32   56.07M    1.59%   286.660000
# 308 2021-03-29  293.30  289.72  294.09  289.26   43.68M    0.71%   291.220000
# 309 2021-03-30  293.25  294.86  295.72   291.5   38.81M   -0.02%   293.300000
# 310 2021-03-31  291.02     294  294.42  290.26   47.00M   -0.76%   293.250000
#
# [61 rows x 8 columns]

# %%
train_data['test_data_price']=test_data['Price']
train_data['predictions']=test_data['predictions']
# Out:
# C:\Users\shanj\AppData\Local\Temp\ipykernel_31196\1394921403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['test_data_price']=test_data['Price']
# C:\Users\shanj\AppData\Local\Temp\ipykernel_31196\1394921403.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['predictions']=test_data['predictions']

# %%
train_data
# Out:
#           Date   Price    Open    High     Low    Vol. Change %  \
# 0   2020-01-03  255.00  255.99  258.19   253.7  35.85M    0.10%
# 1   2020-01-06  253.90  254.75  254.84   251.4  22.35M   -0.43%
# 2   2020-01-08  259.15  253.57  259.15  253.03  40.82M    2.07%
# 3   2020-01-09  257.99   259.4  261.76  257.01  38.33M   -0.45%
# 4   2020-01-10  258.19  257.86  259.25  256.88  18.85M    0.08%
# ..         ...     ...     ...     ...     ...     ...      ...
# 305 2021-03-24  285.79   283.4     288  282.25  46.41M    1.13%
# 306 2021-03-25  286.66   286.5  287.03  283.85  35.22M    0.30%
# 307 2021-03-26  291.22  288.63  292.75  288.32  56.07M    1.59%
# 308 2021-03-29  293.30  289.72  294.09  289.26  43.68M    0.71%
# 309 2021-03-30  293.25  294.86  295.72   291.5  38.81M   -0.02%
#
#      test_data_price  predictions
# 0                NaN          NaN
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# ..               ...          ...
# 305           285.79       282.60
# 306           286.66       285.79
# 307           291.22       286.66
# 308           293.30       291.22
# 309           293.25       293.30
#
# [310 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(train_data['Date'], train_data['Price'], label='Price')
plt.plot(train_data['Date'], train_data['predictions'], label='SMA')

# %%
train_data.head(22)
# Out:
#          Date   Price    Open    High     Low    Vol. Change %       SMA  \
# 0  2020-01-03  255.00  255.99  258.19   253.7  35.85M    0.10%       NaN
# 1  2020-01-06  253.90  254.75  254.84   251.4  22.35M   -0.43%       NaN
# 2  2020-01-08  259.15  253.57  259.15  253.03  40.82M    2.07%       NaN
# 3  2020-01-09  257.99   259.4  261.76  257.01  38.33M   -0.45%       NaN
# 4  2020-01-10  258.19  257.86  259.25  256.88  18.85M    0.08%       NaN
# 5  2020-01-13  262.40   258.3   262.4  257.15  25.86M    1.63%       NaN
# 6  2020-01-14  259.05   262.5  263.22  258.62  31.13M   -1.28%       NaN
# 7  2020-01-15  256.31  258.49  258.91  254.21  49.36M   -1.06%       NaN
# 8  2020-01-16  257.51  257.11  259.51   256.1  40.25M    0.47%       NaN
# 9  2020-01-17  262.50   258.2  262.82  257.75  44.91M    1.94%       NaN
# 10 2020-01-20  266.28   263.2  266.97   261.8  29.80M    1.44%       NaN
# 11 2020-01-21  268.06   265.5   268.9  263.02  38.08M    0.67%       NaN
# 12 2020-01-22  266.54  268.72   270.8   265.5  44.28M   -0.57%       NaN
# 13 2020-01-23  263.73  264.64  266.89  262.24  40.60M   -1.05%       NaN
# 14 2020-01-24  265.49   264.5   267.5  264.21  27.34M    0.67%       NaN
# 15 2020-01-27  255.32     261   262.1  255.32  56.45M   -3.83%       NaN
# 16 2020-01-28  257.70     257  258.84   254.1  48.14M    0.93%       NaN
# 17 2020-01-29  259.94   258.4  261.57  257.61  35.05M    0.87%       NaN
# 18 2020-01-30  257.31     258  258.69  255.27  31.77M   -1.01%       NaN
# 19 2020-01-31  252.20   258.5   259.2  252.17  47.92M   -1.99%       NaN
# 20 2020-02-03  253.99   251.8  254.96   251.1  52.73M    0.71%  259.7285
# 21 2020-02-04  255.40   255.3  257.38   252.9  49.79M    0.56%  259.6780
#
#           SD         UBB         LBB
# 0        NaN         NaN         NaN
# 1        NaN         NaN         NaN
# 2        NaN         NaN         NaN
# 3        NaN         NaN         NaN
# 4        NaN         NaN         NaN
# 5        NaN         NaN         NaN
# 6        NaN         NaN         NaN
# 7        NaN         NaN         NaN
# 8        NaN         NaN         NaN
# 9        NaN         NaN         NaN
# 10       NaN         NaN         NaN
# 11       NaN         NaN         NaN
# 12       NaN         NaN         NaN
# 13       NaN         NaN         NaN
# 14       NaN         NaN         NaN
# 15       NaN         NaN         NaN
# 16       NaN         NaN         NaN
# 17       NaN         NaN         NaN
# 18       NaN         NaN         NaN
# 19       NaN         NaN         NaN
# 20  4.518977  268.766453  250.690547
# 21  4.579833  268.837666  250.518334

# %%
def calculate_bollinger_bands(train_data, window=20, num_std_dev=2, price_column='Price'):
    # Calculate the Simple Moving Average (SMA)
    train_data['SMA'] = train_data[price_column].rolling(window=window).mean().shift()

    # Calculate the Standard Deviation (SD)
    train_data['SD'] = train_data[price_column].rolling(window=window).std().shift()

    # Calculate the Upper Bollinger Band (UBB) and Lower Bollinger Band (LBB)
    train_data['UBB'] = train_data['SMA'] + num_std_dev * train_data['SD']
    train_data['LBB'] = train_data['SMA'] - num_std_dev * train_data['SD']

    return train_data



# Calculate Bollinger Bands
train_data = calculate_bollinger_bands(train_data)

# Display the DataFrame with Bollinger Bands
print(train_data)
# Out:
#           Date   Price    Open    High     Low    Vol. Change %       SMA  \
# 0   2020-01-03  255.00  255.99  258.19   253.7  35.85M    0.10%       NaN
# 1   2020-01-06  253.90  254.75  254.84   251.4  22.35M   -0.43%       NaN
# 2   2020-01-08  259.15  253.57  259.15  253.03  40.82M    2.07%       NaN
# 3   2020-01-09  257.99   259.4  261.76  257.01  38.33M   -0.45%       NaN
# 4   2020-01-10  258.19  257.86  259.25  256.88  18.85M    0.08%       NaN
# ..         ...     ...     ...     ...     ...     ...      ...       ...
# 306 2021-03-25  286.66   286.5  287.03  283.85  35.22M    0.30%  281.2430
# 307 2021-03-26  291.22  288.63  292.75  288.32  56.07M    1.59%  281.9810
# 308 2021-03-29  293.30  289.72  294.09  289.26  43.68M    0.71%  283.0065
# 309 2021-03-30  293.25  294.86  295.72   291.5  38.81M   -0.02%  284.1630
# 310 2021-03-31  291.02     294  294.42  290.26  47.00M   -0.76%  285.1465
#
#            SD         UBB         LBB
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
# ..        ...         ...         ...
# 306  6.756816  294.756631  267.729369
# 307  6.483160  294.947321  269.014679
# 308  6.223414  295.453327  270.559673
# 309  5.850404  295.863807  272.462193
# 310  5.626747  296.399995  273.893005
#
# [311 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Price'], label='Price')
plt.plot(df['Date'], df['SMA'], label='SMA')
plt.plot(df['Date'], df['UBB'], label='Upper Bollinger Band')
plt.plot(df['Date'], df['LBB'], label='Lower Bollinger Band')
plt.title('Bollinger Bands')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
def calculate_profit(train_data):
    # Initialize variables
    balance = 10000  # Initial balance in USD
    shares = 0
    position = None
    buy_price = None
    profit = 0

    # Iterate through each row in the DataFrame
    for index, row in train_data.iterrows():
        close_price = row['Price']
        upper_band = row['UBB']
        lower_band = row['LBB']

        # Buy condition: price is below the lower Bollinger Band
        if close_price < lower_band:
            if position != 'buy':
                shares = balance / close_price
                buy_price = close_price
                balance = 0
                position = 'buy'
            else:
                 position='hold'

        # Sell condition: price is above the upper Bollinger Band
        elif close_price > upper_band:
            if position != 'sell' and shares>0:
                balance = shares * close_price
                profit += balance - 10000  # Subtract initial balance
                shares = 0
                position = 'sell'
            else:
                 position='hold'
        else:
            position='hold'
        print(close_price,position,shares,balance,shares*close_price,(shares*close_price)+balance-10000,row['Date'])  
      

    # Sell remaining shares at the last data point
    if position == 'buy':
        balance = shares * df.iloc[-1]['Price']
        profit += balance - 10000  # Subtract initial balance
        

    return profit

# Example usage:
# Calculate Bollinger Bands
train_data = calculate_bollinger_bands(train_data)

# Calculate profit
profit = calculate_profit(train_data[train_data['Date'] > '2020-12-31'])
print("Profit from Bollinger Bands trading strategy: ${:.2f}".format(profit))
# Out:
# 272.0 hold 0 10000 0.0 0.0 2021-01-04 00:00:00
# 275.2 hold 0 10000 0.0 0.0 2021-01-05 00:00:00
# 272.93 hold 0 10000 0.0 0.0 2021-01-06 00:00:00
# 283.64 hold 0 10000 0.0 0.0 2021-01-08 00:00:00
# 289.49 hold 0 10000 0.0 0.0 2021-01-11 00:00:00
# 289.99 hold 0 10000 0.0 0.0 2021-01-12 00:00:00
# 283.78 hold 0 10000 0.0 0.0 2021-01-13 00:00:00
# 284.79 hold 0 10000 0.0 0.0 2021-01-14 00:00:00
# 276.9 hold 0 10000 0.0 0.0 2021-01-15 00:00:00
# 279.79 hold 0 10000 0.0 0.0 2021-01-18 00:00:00
# 278.19 hold 0 10000 0.0 0.0 2021-01-19 00:00:00
# 279.8 hold 0 10000 0.0 0.0 2021-01-20 00:00:00
# 274.4 hold 0 10000 0.0 0.0 2021-01-21 00:00:00
# 268.25 hold 0 10000 0.0 0.0 2021-01-22 00:00:00
# 265.3 hold 0 10000 0.0 0.0 2021-01-25 00:00:00
# 269.34 hold 0 10000 0.0 0.0 2021-01-26 00:00:00
# 265.5 hold 0 10000 0.0 0.0 2021-01-27 00:00:00
# 265.96 hold 0 10000 0.0 0.0 2021-01-28 00:00:00
# 258.11 buy 38.7431715160203 0 10000.0 0.0 2021-01-29 00:00:00
# 263.8 hold 38.7431715160203 0 10220.448645926155 220.44864592615522 2021-02-01 00:00:00
# 263.15 hold 38.7431715160203 0 10195.26558444074 195.26558444073999 2021-02-02 00:00:00
# 263.53 hold 38.7431715160203 0 10209.987989616828 209.9879896168277 2021-02-03 00:00:00
# 270.11 hold 38.7431715160203 0 10464.918058192243 464.9180581922428 2021-02-04 00:00:00
# 271.7 hold 38.7431715160203 0 10526.519700902714 526.5197009027142 2021-02-05 00:00:00
# 275.2 hold 38.7431715160203 0 10662.120801208785 662.1208012087845 2021-02-08 00:00:00
# 268.98 hold 38.7431715160203 0 10421.13827437914 421.13827437914006 2021-02-09 00:00:00
# 265.9 hold 38.7431715160203 0 10301.809306109795 301.8093061097952 2021-02-10 00:00:00
# 264.7 hold 38.7431715160203 0 10255.317500290572 255.31750029057184 2021-02-11 00:00:00
# 266.0 hold 38.7431715160203 0 10305.683623261399 305.6836232613987 2021-02-12 00:00:00
# 271.81 hold 38.7431715160203 0 10530.781449769476 530.7814497694762 2021-02-15 00:00:00
# 270.9 hold 38.7431715160203 0 10495.525163689897 495.52516368989745 2021-02-16 00:00:00
# 270.9 hold 38.7431715160203 0 10495.525163689897 495.52516368989745 2021-02-17 00:00:00
# 266.99 hold 38.7431715160203 0 10344.03936306226 344.03936306226024 2021-02-18 00:00:00
# 271.34 hold 38.7431715160203 0 10512.572159156947 512.5721591569472 2021-02-19 00:00:00
# 270.51 hold 38.7431715160203 0 10480.41532679865 480.4153267986494 2021-02-20 00:00:00
# 273.71 hold 38.7431715160203 0 10604.393475649915 604.3934756499148 2021-02-22 00:00:00
# 271.9 hold 38.7431715160203 0 10534.268335205918 534.2683352059175 2021-02-24 00:00:00
# 270.71 hold 38.7431715160203 0 10488.163961101855 488.1639611018545 2021-02-25 00:00:00
# 270.17 hold 38.7431715160203 0 10467.242648483205 467.2426484832049 2021-02-26 00:00:00
# 273.58 hold 38.7431715160203 0 10599.356863352832 599.3568633528321 2021-03-01 00:00:00
# 279.1 sell 0 10813.219170121265 0.0 813.219170121265 2021-03-02 00:00:00
# 278.01 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-03 00:00:00
# 274.75 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-04 00:00:00
# 277.5 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-05 00:00:00
# 285.79 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-09 00:00:00
# 282.24 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-10 00:00:00
# 286.0 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-11 00:00:00
# 284.93 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-12 00:00:00
# 292.74 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-15 00:00:00
# 292.33 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-16 00:00:00
# 283.35 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-17 00:00:00
# 279.25 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-18 00:00:00
# 285.47 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-19 00:00:00
# 288.65 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-22 00:00:00
# 282.6 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-23 00:00:00
# 285.79 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-24 00:00:00
# 286.66 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-25 00:00:00
# 291.22 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-26 00:00:00
# 293.3 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-29 00:00:00
# 293.25 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-30 00:00:00
# 291.02 hold 0 10813.219170121265 0.0 813.219170121265 2021-03-31 00:00:00
# Profit from Bollinger Bands trading strategy: $813.22
